# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/benoit/.pyenv/versions/3.8.6/envs/diving/lib/python3.8/site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.17.3 in /Users/benoit/.pyenv/versions/3.8.6/envs/diving/lib/python3.8/site-packages (from opencv-python) (1.17.5)

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['Up', 'Down', 'Reserve', 'Stop', 'NoAir']
number_imgs = 15

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # 4. Capture Images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for OK
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting images for NotOK
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting images for HalfBottle
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting images for Reserve
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting images for Down
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting images for Up
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting images for Stop
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting images for End
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting images for NoAir
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting images for Regroup
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14

# %% [markdown]
# # 5. Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Requirement already satisfied: pyqt5 in /Users/benoit/.pyenv/versions/3.8.6/envs/diving/lib/python3.8/site-packages (5.15.4)
# Requirement already satisfied: lxml in /Users/benoit/.pyenv/versions/3.8.6/envs/diving/lib/python3.8/site-packages (4.6.3)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in /Users/benoit/.pyenv/versions/3.8.6/envs/diving/lib/python3.8/site-packages (from pyqt5) (12.8.1)
# Requirement already satisfied: PyQt5-Qt5>=5.15 in /Users/benoit/.pyenv/versions/3.8.6/envs/diving/lib/python3.8/site-packages (from pyqt5) (5.15.2)

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# make: *** No rule to make target `qt5py3'.  Stop.

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# labelImg.py:950: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   bar.setValue(bar.value() + bar.singleStep() * units)

# %% [markdown]
# # 6. Move them into a Training and Testing Partition

# %% [markdown]
# # OPTIONAL - 7. Compress them for Colab Training

# %%
TRAIN_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')
TEST_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'test')
ARCHIVE_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'archive.tar.gz')

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- ----------
# absl-py                           0.11.0
# aiobotocore                       1.2.1
# aiohttp                           3.7.3
# aioitertools                      0.7.1
# alembic                           1.4.1
# altair                            4.1.0
# anyio                             2.0.2
# appdirs                           1.4.4
# appnope                           0.1.2
# argon2-cffi                       20.1.0
# args                              0.1.0
# astor                             0.8.1
# astroid                           2.4.2
# astunparse                        1.6.3
# async-generator                   1.10
# async-timeout                     3.0.1
# attrs                             20.3.0
# Automat                           20.2.0
# autopep8                          1.5.4
# Babel                             2.9.0
# backcall                          0.2.0
# base58                            2.1.0
# beautifulsoup4                    4.9.3
# black                             20.8b1
# bleach                            3.2.1
# blinker                           1.4
# botocore                          1.19.52
# branca                            0.4.2
# bs4                               0.0.1
# cachetools                        4.2.0
# certifi                           2020.12.5
# cffi                              1.14.4
# chardet                           3.0.4
# click                             7.1.2
# cloudpickle                       1.6.0
# cmdstanpy                         0.9.5
# colorama                          0.4.4
# confuse                           1.4.0
# constantly                        15.1.0
# convertdate                       2.3.0
# coverage                          5.4
# cryptography                      3.4.6
# cssselect                         1.1.0
# cycler                            0.10.0
# Cython                            0.29.17
# databricks-cli                    0.14.1
# dataclasses                       0.6
# decorator                         4.4.2
# defusedxml                        0.6.0
# dill                              0.3.3
# dm-tree                           0.1.5
# docker                            4.4.3
# docutils                          0.16
# entrypoints                       0.3
# ephem                             3.7.7.1
# fastapi                           0.63.0
# fbprophet                         0.7.1
# flake8                            3.8.4
# Flask                             1.1.2
# flatbuffers                       1.12
# folium                            0.12.1
# fsspec                            0.8.5
# future                            0.18.2
# fuzzywuzzy                        0.18.0
# gast                              0.3.3
# gcsfs                             0.7.2
# gensim                            3.8.3
# gin-config                        0.4.0
# gitdb                             4.0.5
# GitPython                         3.1.13
# google-api-core                   1.26.0
# google-api-python-client          2.1.0
# google-auth                       1.24.0
# google-auth-httplib2              0.1.0
# google-auth-oauthlib              0.4.2
# google-cloud-bigquery             2.13.1
# google-cloud-core                 1.6.0
# google-cloud-storage              1.36.0
# google-crc32c                     1.1.2
# google-pasta                      0.2.0
# google-resumable-media            1.2.0
# google-trans-new                  1.1.9
# googleapis-common-protos          1.52.0
# grpcio                            1.32.0
# gunicorn                          20.0.4
# h11                               0.12.0
# h5py                              2.10.0
# hijri-converter                   2.1.1
# holidays                          0.10.5.2
# htmlmin                           0.1.12
# httplib2                          0.19.1
# hyperlink                         21.0.0
# idna                              2.10
# ImageHash                         4.2.0
# imageio                           2.9.0
# importlib-resources               5.1.2
# incremental                       17.5.0
# iniconfig                         1.1.1
# install                           1.3.4
# ipdb                              0.13.4
# ipykernel                         5.4.2
# ipython                           7.19.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.6.3
# isort                             5.7.0
# itemadapter                       0.2.0
# itemloaders                       1.0.4
# itsdangerous                      1.1.0
# jedi                              0.18.0
# Jinja2                            2.11.2
# jmespath                          0.10.0
# joblib                            1.0.0
# json5                             0.9.5
# jsonschema                        3.2.0
# jupyter                           1.0.0
# jupyter-client                    6.1.11
# jupyter-console                   6.2.0
# jupyter-contrib-core              0.3.3
# jupyter-contrib-nbextensions      0.5.1
# jupyter-core                      4.7.0
# jupyter-highlight-selected-word   0.2.0
# jupyter-latex-envs                1.4.6
# jupyter-nbextensions-configurator 0.4.1
# jupyter-server                    1.2.1
# jupyterlab                        3.0.3
# jupyterlab-pygments               0.1.2
# jupyterlab-server                 2.1.1
# jupyterlab-widgets                1.0.0
# jupyterthemes                     0.20.0
# kaggle                            1.5.12
# Keras-Preprocessing               1.1.2
# keras-tuner                       1.0.2
# keyring                           22.0.1
# kiwisolver                        1.3.1
# korean-lunar-calendar             0.2.1
# lazy-object-proxy                 1.4.3
# lesscpy                           0.14.0
# llvmlite                          0.35.0
# LunarCalendar                     0.0.9
# lxml                              4.6.3
# Mako                              1.1.4
# Markdown                          3.3.3
# MarkupSafe                        1.1.1
# matplotlib                        3.3.3
# mccabe                            0.6.1
# memoized-property                 1.0.3
# missingno                         0.4.2
# mistune                           0.8.4
# mlflow                            1.14.0
# multidict                         5.1.0
# mypy-extensions                   0.4.3
# nbclassic                         0.2.6
# nbclient                          0.5.1
# nbconvert                         6.0.7
# nbformat                          5.0.8
# nbgrader                          0.6.1
# nbresult                          0.0.3
# nest-asyncio                      1.4.3
# networkx                          2.5
# nltk                              3.5
# notebook                          6.1.6
# numba                             0.52.0
# numpy                             1.19.5
# oauth2client                      4.1.3
# oauthlib                          3.1.0
# opencv-python                     4.5.1.48
# opencv-python-headless            4.5.1.48
# opt-einsum                        3.3.0
# packaging                         20.8
# packgenlite                       1.1.2
# pandas                            1.0.3
# pandas-profiling                  2.10.0
# pandocfilters                     1.4.3
# parsel                            1.6.0
# parso                             0.8.1
# pathspec                          0.8.1
# patsy                             0.5.1
# pexpect                           4.8.0
# phik                              0.11.0
# pickleshare                       0.7.5
# Pillow                            8.1.0
# pip                               21.0.1
# pkginfo                           1.7.0
# plotly                            4.14.1
# pluggy                            0.13.1
# ply                               3.11
# pmdarima                          1.8.0
# prometheus-client                 0.9.0
# prometheus-flask-exporter         0.18.1
# promise                           2.3
# prompt-toolkit                    3.0.10
# Protego                           0.1.16
# proto-plus                        1.18.1
# protobuf                          3.14.0
# psutil                            5.8.0
# ptyprocess                        0.7.0
# py                                1.10.0
# py-cpuinfo                        7.0.0
# pyarrow                           3.0.0
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycocotools                       2.0.2
# pycodestyle                       2.6.0
# pycparser                         2.20
# pydantic                          1.7.3
# pydeck                            0.6.1
# PyDispatcher                      2.0.5
# pyflakes                          2.2.0
# Pygments                          2.7.3
# PyHamcrest                        2.0.2
# pylint                            2.6.0
# PyMeeus                           0.3.7
# pymongo                           3.11.3
# pyOpenSSL                         20.0.1
# pyparsing                         2.4.7
# PyQt5                             5.15.4
# PyQt5-Qt5                         5.15.2
# PyQt5-sip                         12.8.1
# pyrsistent                        0.17.3
# pystan                            2.19.1.1
# pytest                            6.2.1
# python-dateutil                   2.8.1
# python-editor                     1.0.4
# python-gitlab                     2.6.0
# python-slugify                    4.0.1
# pytz                              2020.5
# PyWavelets                        1.1.1
# PyYAML                            5.3.1
# pyzmq                             20.0.0
# qtconsole                         5.0.2
# QtPy                              1.9.0
# querystring-parser                1.2.4
# queuelib                          1.5.0
# readme-renderer                   28.0
# regex                             2020.11.13
# requests                          2.25.1
# requests-oauthlib                 1.3.0
# requests-toolbelt                 0.9.1
# retrying                          1.3.3
# rfc3986                           1.4.0
# rsa                               4.7
# s3fs                              0.5.2
# scikit-image                      0.18.1
# scikit-learn                      0.22
# scikit-surprise                   1.1.0
# scipy                             1.6.0
# Scrapy                            2.4.1
# seaborn                           0.11.1
# selenium                          3.141.0
# Send2Trash                        1.5.0
# sentencepiece                     0.1.95
# seqeval                           1.2.2
# service-identity                  18.1.0
# setuptools                        49.2.1
# setuptools-git                    1.2
# setuptools-scm                    5.0.1
# six                               1.15.0
# smart-open                        4.2.0
# smmap                             3.0.5
# sniffio                           1.2.0
# soupsieve                         2.1
# SQLAlchemy                        1.3.22
# sqlparse                          0.4.1
# starlette                         0.13.6
# statsmodels                       0.12.2
# streamlit                         0.77.0
# sudo                              1.0.0
# tabulate                          0.8.7
# tangled-up-in-unicode             0.0.6
# tensorboard                       2.4.0
# tensorboard-plugin-wit            1.7.0
# tensorflow                        2.4.0
# tensorflow-addons                 0.12.1
# tensorflow-datasets               4.2.0
# tensorflow-estimator              2.4.0
# tensorflow-hub                    0.11.0
# tensorflow-metadata               0.29.0
# tensorflow-model-optimization     0.5.0
# termcolor                         1.1.0
# terminado                         0.9.2
# terminaltables                    3.1.0
# testpath                          0.4.4
# text-unidecode                    1.3
# tf-models-official                2.4.0
# tf-slim                           1.1.0
# threadpoolctl                     2.1.0
# tifffile                          2021.2.1
# toml                              0.10.2
# toolz                             0.11.1
# torch                             1.7.1
# tornado                           6.1
# tqdm                              4.56.0
# traitlets                         5.0.5
# twine                             3.3.0
# Twisted                           20.3.0
# typed-ast                         1.4.2
# typeguard                         2.11.1
# typing-extensions                 3.7.4.3
# tzlocal                           2.1
# uritemplate                       3.0.1
# urllib3                           1.26.2
# uvicorn                           0.13.4
# validators                        0.18.2
# visions                           0.6.0
# w3lib                             1.22.0
# wcwidth                           0.2.5
# webencodings                      0.5.1
# websocket-client                  0.57.0
# Werkzeug                          1.0.1
# wheel                             0.36.2
# widgetsnbextension                3.5.1
# wrapt                             1.12.1
# xgboost                           1.3.3
# XlsxWriter                        1.3.7
# yapf                              0.30.0
# yarl                              1.6.3
# zope.interface                    5.2.0
